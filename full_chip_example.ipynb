# %%
import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, open_docs

# %%
design = metal.designs.DesignPlanar()
gui = metal.MetalGUI(design)

design.overwrite_enabled = True
design.chips.main
# Out:
# {'material': 'silicon',
#  'layer_start': '0',
#  'layer_end': '2048',
#  'size': {'center_x': '0.0mm',
#   'center_y': '0.0mm',
#   'center_z': '0.0mm',
#   'size_x': '9mm',
#   'size_y': '6mm',
#   'size_z': '-750um',
#   'sample_holder_top': '890um',
#   'sample_holder_bottom': '1650um'}}

# %%
# here we will import what we need:
## Transmon
from qiskit_metal.qlibrary.qubits.transmon_pocket_6 import TransmonPocket6
from qiskit_metal.qlibrary.qubits.transmon_cross_fl import TransmonCrossFL


## Launchers
from qiskit_metal.qlibrary.terminations.launchpad_wb import LaunchpadWirebond
from qiskit_metal.qlibrary.terminations.launchpad_wb_coupled import LaunchpadWirebondCoupled

## busses and connectors
from qiskit_metal.qlibrary.tlines.pathfinder import RoutePathfinder
from qiskit_metal.qlibrary.tlines.meandered import RouteMeander
from qiskit_metal.qlibrary.tlines.anchored_path import RouteAnchors

## Lumped elements
from qiskit_metal.qlibrary.lumped.cap_n_interdigital import CapNInterdigital
from qiskit_metal.qlibrary.couplers.cap_n_interdigital_tee import CapNInterdigitalTee
from qiskit_metal.qlibrary.couplers.coupled_line_tee import CoupledLineTee


## Tunable Coupler
from qiskit_metal.qlibrary.couplers.tunable_coupler_01 import TunableCoupler01

# %% [markdown]
# ## Design
# First we will create the design of the chip.

# %% [markdown]
# ### Qubits

# %%
# with this function we can get the option of every component
TransmonPocket6.get_template_options(design)
# Out:
# {'pos_x': '0.0um',
#  'pos_y': '0.0um',
#  'orientation': '0.0',
#  'chip': 'main',
#  'layer': '1',
#  'connection_pads': {},
#  '_default_connection_pads': {'pad_gap': '15um',
#   'pad_width': '125um',
#   'pad_height': '30um',
#   'pad_cpw_shift': '0um',
#   'pad_cpw_extent': '25um',
#   'cpw_width': '10um',
#   'cpw_gap': '6um',
#   'cpw_extend': '100um',
#   'pocket_extent': '5um',
#   'pocket_rise': '0um',
#   'loc_W': '+1',
#   'loc_H': '+1'},
#  'pad_gap': '30um',
#  'inductor_width': '20um',
#  'pad_width': '455um',
#  'pad_height': '90um',
#  'pocket_width': '650um',
#  'pocket_height': '650um',
#  'hfss_wire_bonds': False,
#  'q3d_wire_bonds': False,
#  'hfss_inductance': '10nH',
#  'hfss_capacitance': 0,
#  'hfss_resistance': 0,
#  'hfss_mesh_kw_jj': 7e-06,
#  'q3d_inductance': '10nH',
#  'q3d_capacitance': 0,
#  'q3d_resistance': 0,
#  'q3d_mesh_kw_jj': 7e-06,
#  'gds_cell_name': 'my_other_junction'}

# %%
# add transmon qubit
options=Dict(
    pos_x='0.0mm',
    pos_y='-1mm',
    gds_cell_name='FakeJunction01',
    hfss_inductance='14nH',
    pad_width='425um',
    pocket_height='650um',
    connection_pads=Dict(
        readout = dict(loc_W=0, loc_H=-1, pad_width='80um', pad_gap='50um'),
        bus_01 = dict(loc_W=-1, loc_H=-1, pad_width='60um', pad_gap='10um'),
        bus_02 = dict(loc_W=-1, loc_H=+1, pad_width='60um', pad_gap='10um'),
        bus_03 = dict(loc_W=0, loc_H=+1, pad_width='90um', pad_gap='30um'),
        bus_04 = dict(loc_W=+1, loc_H=+1, pad_width='60um', pad_gap='10um'),
        bus_05 = dict(loc_W=+1, loc_H=-1, pad_width='60um', pad_gap='10um'),
    )
)

Q_main = TransmonPocket6(design=design, name='Q_main', options=options)

gui.rebuild()
gui.autoscale()
# Out:
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# ...

# %%
TransmonCrossFL.get_template_options(design)
# Out:
# {'pos_x': '0.0um',
#  'pos_y': '0.0um',
#  'orientation': '0.0',
#  'chip': 'main',
#  'layer': '1',
#  'connection_pads': {},
#  '_default_connection_pads': {'connector_type': '0',
#   'claw_length': '30um',
#   'ground_spacing': '5um',
#   'claw_width': '10um',
#   'claw_gap': '6um',
#   'connector_location': '0'},
#  'cross_width': '20um',
#  'cross_length': '200um',
#  'cross_gap': '20um',
#  'make_fl': True,
#  'fl_options': {'t_top': '15um',
#   't_offset': '0um',
#   't_inductive_gap': '3um',
#   't_width': '5um',
#   't_gap': '3um'},
#  'hfss_wire_bonds': False,
#  'q3d_wire_bonds': False,
#  'hfss_inductance': '10nH',
#  'hfss_capacitance': 0,
#  'hfss_resistance': 0,
#  'hfss_mesh_kw_jj': 7e-06,
#  'q3d_inductance': '10nH',
#  'q3d_capacitance': 0,
#  'q3d_resistance': 0,
#  'q3d_mesh_kw_jj': 7e-06,
#  'gds_cell_name': 'my_other_junction'}

# %%
# We will add the cross Qubit

##  options for the qubits
options1=Dict(
    pos_x='-2.75mm',
    pos_y='-1.8mm',
    connection_pads=Dict(
        bus_01 = dict(connector_location='180', claw_length='95um'),
        readout = dict(connector_location='0'),
    ),
    fl_options=dict(),
)

options2=Dict(
    pos_x='-2.75mm',
    pos_y='-1.2mm',
    orientation='180',
    connection_pads=Dict(
        bus_02 = dict(connector_location='0', claw_length='95um'),
        readout = dict(connector_location='180'),
    ),
    fl_options=dict(),
)

options_tune = Dict(
    pos_x='-2.81mm',
    pos_y='-1.5mm',
    orientation='90',
    c_width='500um'
)

Q1 = TransmonCrossFL(design=design, name='Q1', options=options1)
Q2 = TransmonCrossFL(design=design, name='Q2', options=options2)
tune_c_Q12 = TunableCoupler01(design=design, name='Tune_C_Q12', options=options_tune)

gui.rebuild()
gui.autoscale()
# Out:
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# ...

# %%
# adding the rest of the pocket transmons

options3=Dict(
    pos_x='-3mm',
    pos_y='0.5mm',
    gds_cell_name='FakeJunction01',
    hfss_inductance='14nH',
    connection_pads=Dict(
        readout = dict(loc_W=0, loc_H=1, pad_width='80um', pad_gap='50um'),
        bus_03 = dict(loc_W=0, loc_H=-1, pad_width='80um', pad_gap='15um'),
        bus_34 = dict(loc_W=1, loc_H=-1, pad_width='80um', pad_gap='15um'),
    )
)

options4=Dict(
    pos_x='0mm',
    pos_y='1mm',
    gds_cell_name='FakeJunction01',
    hfss_inductance='14nH',
    connection_pads=Dict(
        readout = dict(loc_W=0, loc_H=1, pad_width='80um', pad_gap='50um'),
        bus_04 = dict(loc_W=0, loc_H=-1, pad_width='80um', pad_gap='15um'),
        bus_34 = dict(loc_W=-1, loc_H=-1, pad_width='80um', pad_gap='15um'),
        bus_45 = dict(loc_W=1, loc_H=-1, pad_width='80um', pad_gap='15um'),
    )
)

options5=Dict(
    pos_x='3mm',
    pos_y='0.5mm',
    gds_cell_name='FakeJunction01',
    hfss_inductance='14nH',
    connection_pads=Dict(
        readout = dict(loc_W=0, loc_H=1, pad_width='80um', pad_gap='50um'),
        bus_05 = dict(loc_W=0, loc_H=-1, pad_width='80um', pad_gap='15um'),
        bus_45 = dict(loc_W=-1, loc_H=-1, pad_width='80um', pad_gap='15um'),
    )
)

Q3 = TransmonPocket6(design=design, name='Q3', options=options3)
Q4 = TransmonPocket6(design=design, name='Q4', options=options4)
Q5 = TransmonPocket6(design=design, name='Q5', options=options5)

gui.rebuild()
gui.autoscale()
# Out:
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# ...

# %% [markdown]
# ### Busses

# %%
# bus length calculator
from qiskit_metal.analyses.em.cpw_calculations import guided_wavelength

def find_resonator_length(frequency, line_width, line_gap, N):

    [lambdaG, etfSqrt, q] = guided_wavelength(frequency*10**9, line_width*10**-6,line_gap*10**-6, 750*10**-6, 200*10**-9)

    return str(lambdaG/N*10**3) + ' mm'

# %%
# Couple crossmons to the main qubit

options01=Dict(
    pin_inputs=Dict(
        start_pin=Dict(
            component='Q_main',
            pin='bus_01',
        ),
        end_pin=Dict(
            component='Q1',
            pin='bus_01',
        ),
    ),
    fillet='99um',
    lead=Dict(
        start_straight='125um',
        end_straight='225um'
    ),
    total_length='6mm',
    meander=Dict(asymmetry='1000um'),
    hfss_wire_bonds= True
)

options02=Dict(
    pin_inputs=Dict(
        start_pin=Dict(
            component='Q_main',
            pin='bus_02',
        ),
        end_pin=Dict(
            component='Q2',
            pin='bus_02',
        ),
    ),
    fillet='99um',
    lead=Dict(
        start_straight='325um',
        end_straight='125um'
    ),
    total_length='6.4mm',
    meander=Dict(asymmetry='450um'),
    hfss_wire_bonds= True
)

bus_01 = RouteMeander(design=design, name='Bus01', options=options01)
bus_02 = RouteMeander(design=design, name='Bus02', options=options02)

gui.rebuild()
gui.autoscale()
# Out:
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# ...

# %%
# connecting main qubit to other floating pockets


options03=Dict(
    pin_inputs=Dict(
        start_pin=Dict(
            component='Q_main',
            pin='bus_03',
        ),
        end_pin=Dict(
            component='Q3',
            pin='bus_03',
        ),
    ),
    fillet='99um',
    lead=Dict(
        start_straight='125um',
        end_straight='125um'
    ),
    total_length='6.8mm',
    meander=Dict(asymmetry='-100um'),
    hfss_wire_bonds= True
)

options04=Dict(
    pin_inputs=Dict(
        start_pin=Dict(
            component='Q_main',
            pin='bus_04',
        ),
        end_pin=Dict(
            component='Q4',
            pin='bus_04',
        ),
    ),
    fillet='99um',
    lead=Dict(
        start_straight='525um',
        end_straight='125um'
    ),
    total_length='6.4mm',
    meander=Dict(asymmetry='-350um'),
    hfss_wire_bonds= True
)

options05=Dict(
    pin_inputs=Dict(
        start_pin=Dict(
            component='Q_main',
            pin='bus_05',
        ),
        end_pin=Dict(
            component='Q5',
            pin='bus_05',
        ),
    ),
    fillet='99um',
    lead=Dict(
        start_straight='500um',
        end_straight='225um'
    ),
    total_length='7.6mm',
    meander=Dict(asymmetry='-200um'),
    hfss_wire_bonds= True
)

bus_03 = RouteMeander(design=design, name='Bus03', options=options03)
bus_04 = RouteMeander(design=design, name='Bus04', options=options04)
bus_05 = RouteMeander(design=design, name='Bus05', options=options05)


gui.rebuild()
gui.autoscale()
# Out:
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# ...

# %%
# Connecting the floating qubits toquether
# connecting main qubit to other floating pockets


options34=Dict(
    pin_inputs=Dict(
        start_pin=Dict(
            component='Q3',
            pin='bus_34',
        ),
        end_pin=Dict(
            component='Q4',
            pin='bus_34',
        ),
    ),
    fillet='99um',
    lead=Dict(
        start_straight='125um',
        end_straight='125um'
    ),
    total_length='6.4mm',
    meander=Dict(asymmetry='-100um'),
    hfss_wire_bonds= True
)

options45=Dict(
    pin_inputs=Dict(
        start_pin=Dict(
            component='Q4',
            pin='bus_45',
        ),
        end_pin=Dict(
            component='Q5',
            pin='bus_45',
        ),
    ),
    fillet='99um',
    lead=Dict(
        start_straight='125um',
        end_straight='25um'
    ),
    total_length='6.8mm',
    meander=Dict(asymmetry='50um'),
    hfss_wire_bonds= True
)


bus_35 = RouteMeander(design=design, name='Bus34', options=options34)
bus_45 = RouteMeander(design=design, name='Bus45', options=options45)


gui.rebuild()
gui.autoscale()
# Out:
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# ...

# %% [markdown]
# ### adding readout and control line

# %%
# read Launchers
options_qmain_read=Dict(
    pos_x='2mm',
    pos_y='-4mm',
    orientation='90'
)

options_q1_read=Dict(
    pos_x='-2mm',
    pos_y='-4mm',
    orientation='90'
)

options_q2_read=Dict(
    pos_x='-5mm',
    pos_y='-1mm',
    orientation='0'
)

options_tc_read=Dict(
    pos_x='-5mm',
    pos_y='-3mm',
    orientation='0'
)

launch_q_main_read = LaunchpadWirebond(design=design, name='Launch_Qmain_Read', options=options_qmain_read)
launch_q1_read = LaunchpadWirebondCoupled(design=design, name='Launch_Q1_Read', options=options_q1_read)
launch_q2_read = LaunchpadWirebondCoupled(design=design, name='Launch_Q2_Read', options=options_q2_read)
launch_tcoup_read = LaunchpadWirebondCoupled(design=design, name='Launch_TuneC_Read', options=options_tc_read)



gui.rebuild()
gui.autoscale()
# Out:
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# ...

# %%
# control Launchers

options_q1_fl=Dict(
    pos_x='0mm',
    pos_y='-4mm',
    orientation='90'
)

options_q2_fl=Dict(
    pos_x='-5mm',
    pos_y='1mm',
    orientation='0'
)

options_tc_fl=Dict(
    pos_x='-4mm',
    pos_y='-4mm',
    orientation='90'
)

launch_q1_fl = LaunchpadWirebond(design=design, name='Launch_Q1_fl', options=options_q1_fl)
launch_q2_fl = LaunchpadWirebond(design=design, name='Launch_Q2_fl', options=options_q2_fl)
launch_tcoup_fl = LaunchpadWirebond(design=design, name='Launch_TuneC_fl', options=options_tc_fl)



gui.rebuild()
gui.autoscale()
# Out:
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# ...

# %%
# launchers ot the transmon qubits
launch_nw = LaunchpadWirebond(design, 'Launch_NW',options = dict(pos_x = '-5mm', pos_y='3mm', orientation=0))
launch_ne = LaunchpadWirebond(design, 'Launch_NE',options = dict(pos_x = '5mm', pos_y='3mm', orientation=180))

gui.rebuild()
gui.autoscale()
# Out:
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# ...

# %%
# Readout busses

options_cap = Dict(
    pos_x='2mm',
    pos_y='-3.5mm',
    orientation='0',
)

read_main_cap = CapNInterdigital(design=design, name='Read_Q_Main_C', options=options_cap) # readout cap for main

options_read_main=Dict(
    pin_inputs=Dict(
        start_pin=Dict(
            component='Q_main',
            pin='readout',
        ),
        end_pin=Dict(
            component='Read_Q_Main_C',
            pin='north_end',
        ),
    ),
    fillet='99um',
    lead=Dict(
        start_straight='100um',
        end_straight='55um'
    ),
    total_length='5.6mm',
    meander=Dict(asymmetry='-700um'),
    hfss_wire_bonds= True
)

options_readq1=Dict(
    pin_inputs=Dict(
        start_pin=Dict(
            component='Q1',
            pin='readout',
        ),
        end_pin=Dict(
            component='Launch_Q1_Read',
            pin='tie',
        ),
    ),
    fillet='99um',
    lead=Dict(
        start_straight='100um',
        end_straight='425um'
    ),
    total_length='6.4mm',
    meander=Dict(asymmetry='-50um'),
    hfss_wire_bonds= True
)

options_readq2=Dict(
    pin_inputs=Dict(
        start_pin=Dict(
            component='Q2',
            pin='readout',
        ),
        end_pin=Dict(
            component='Launch_Q2_Read',
            pin='tie',
        ),
    ),
    fillet='99um',
    lead=Dict(
        start_straight='350um',
        end_straight='0um'
    ),
    total_length='5.4mm',
    meander=Dict(asymmetry='-450um'),
    hfss_wire_bonds= True
)

options_tunetc = Dict(
    pin_inputs=Dict(
        start_pin=Dict(
            component='Tune_C_Q12',
            pin='Control',
        ),
        end_pin=Dict(
            component='Launch_TuneC_Read',
            pin='tie',
        ),
    ),
    fillet='99um',
    lead=Dict(
        start_straight='500um',
        end_straight='25um'
    ),
    total_length='5.8mm',
    meander=Dict(asymmetry='-700um'),
    hfss_wire_bonds= True
)

options_read_main_C = Dict(
    pin_inputs=Dict(
        start_pin=Dict(
            component='Launch_Qmain_Read',
            pin='tie',
        ),
        end_pin=Dict(
            component='Read_Q_Main_C',
            pin='south_end',
        ),
    ),
    lead=Dict(
        start_straight='0um',
        end_straight='0um'
    ),
    hfss_wire_bonds= True
)

read_qmain = RouteMeander(design=design, name='Read_Qmain', options=options_read_main)
read_qmain_Cap = RoutePathfinder(design, name='Read_QMain_C', options=options_read_main_C)
read_q1 = RouteMeander(design=design, name='Read_Q1', options=options_readq1)
read_q2 = RouteMeander(design=design, name='Read_Q2', options=options_readq2)
read_tunetc = RouteMeander(design=design, name='Read_TuneC', options=options_tunetc)

gui.rebuild()
gui.autoscale()
# Out:
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# ...

# %%
# adding flux bias for crossmon and Coupler detuner

options_flux1=Dict(
    pin_inputs=Dict(
        start_pin=Dict(
            component='Q1',
            pin='flux_line',
        ),
        end_pin=Dict(
            component='Launch_Q1_fl',
            pin='tie',
        ),
    ),
    lead=Dict(
        start_straight='25um',
        end_straight='100um',
    ),
    fillet='99um',
    trace_width='5um',
    trace_gap='3um',
    hfss_wire_bonds= True
)

options_tunetcfl = Dict(
    pin_inputs=Dict(
        start_pin=Dict(
            component='Tune_C_Q12',
            pin='Flux',
        ),
        end_pin=Dict(
            component='Launch_TuneC_fl',
            pin='tie',
        ),
    ),
    lead=Dict(
        start_straight='300um',
        end_straight='125um',
    ),
    fillet='99um',
    trace_width='5um',
    trace_gap='3um',
    hfss_wire_bonds= True
)

options_flux2=Dict(
    pin_inputs=Dict(
        start_pin=Dict(
            component='Q2',
            pin='flux_line',
        ),
        end_pin=Dict(
            component='Launch_Q2_fl',
            pin='tie',
        ),
    ),
    lead=Dict(
        start_straight='125um',
        end_straight='1500um',
    ),
    fillet='99um',
    trace_width='5um',
    trace_gap='3um',
    hfss_wire_bonds= True
)

flux_q1 = RoutePathfinder(design=design, name='Flux_Line_Q1', options=options_flux1)
flux_tunetc = RoutePathfinder(design=design, name='Flux_Line_TuneC', options=options_tunetcfl)
flux_q2 = RoutePathfinder(design=design, name='Flux_Line_Q2', options=options_flux2)

gui.rebuild()
gui.autoscale()
# Out:
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# ...

# %%
RoutePathfinder.get_template_options(design)
# Out:
# {'chip': 'main',
#  'layer': '1',
#  'pin_inputs': {'start_pin': {'component': '', 'pin': ''},
#   'end_pin': {'component': '', 'pin': ''}},
#  'fillet': '0',
#  'lead': {'start_straight': '0mm',
#   'end_straight': '0mm',
#   'start_jogged_extension': '',
#   'end_jogged_extension': ''},
#  'total_length': '7mm',
#  'trace_width': 'cpw_width',
#  'anchors': {},
#  'advanced': {'avoid_collision': 'true'},
#  'step_size': '0.25mm',
#  'hfss_wire_bonds': False,
#  'q3d_wire_bonds': False}

# %%
# connecting the transmon pockets to the feeding line
# first add the teecap.

op_read_t3=Dict(
    pos_x='-3mm',
    pos_y='3mm',
    coupling_length='200um',
    open_termination=False
)

q3_read_T = CoupledLineTee(design=design, name='Q3_Read_T', options=op_read_t3)



op_read_t4=Dict(
    pos_x='0mm',
    pos_y='3mm',
    finger_length='0um',
    finger_count = '8',
)

q4_read_T = CapNInterdigitalTee(design=design, name='Q4_Read_T', options=op_read_t4)


op_read_t5=Dict(
    pos_x='3mm',
    pos_y='3mm',
    finger_length='50um',
    finger_count = '11',
)

q5_read_T = CapNInterdigitalTee(design=design, name='Q5_Read_T', options=op_read_t5)

gui.rebuild()
gui.autoscale()
# Out:
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# ...

# %%
# connecting the transmission line
# adding flux bias for crossmon and Coupler detuner

options_tl_01=Dict(
    pin_inputs=Dict(
        start_pin=Dict(
            component='Launch_NW',
            pin='tie',
        ),
        end_pin=Dict(
            component='Q3_Read_T',
            pin='prime_start',
        ),
    ),
    hfss_wire_bonds= True
)

options_tl_02=Dict(
    pin_inputs=Dict(
        start_pin=Dict(
            component='Q3_Read_T',
            pin='prime_end',
        ),
        end_pin=Dict(
            component='Q4_Read_T',
            pin='prime_start',
        ),
    ),
    hfss_wire_bonds= True
)

options_tl_03=Dict(
    pin_inputs=Dict(
        start_pin=Dict(
            component='Q4_Read_T',
            pin='prime_end',
        ),
        end_pin=Dict(
            component='Q5_Read_T',
            pin='prime_start',
        ),
    ),
    hfss_wire_bonds= True
)

options_tl_04=Dict(
    pin_inputs=Dict(
        start_pin=Dict(
            component='Q5_Read_T',
            pin='prime_end',
        ),
        end_pin=Dict(
            component='Launch_NE',
            pin='tie',
        ),
    ),
    hfss_wire_bonds= True
)


tl_01 = RoutePathfinder(design=design, name='TL_01', options=options_tl_01)
tl_02 = RoutePathfinder(design=design, name='TL_02', options=options_tl_02)
tl_03 = RoutePathfinder(design=design, name='TL_03', options=options_tl_03)
tl_04 = RoutePathfinder(design=design, name='TL_04', options=options_tl_04)


gui.rebuild()
gui.autoscale()
# Out:
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:c:\Users\mohamad\anaconda3\envs\metal22\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# ...

# %%
# connecting capacitors to qubits

options_readq3=Dict(
    pin_inputs=Dict(
        start_pin=Dict(
            component='Q3',
            pin='readout',
        ),
        end_pin=Dict(
            component='Q3_Read_T',
            pin='second_end',
        ),
    ),
    fillet='99um',
    lead=Dict(
        start_straight='230um',
        end_straight='100um'
    ),
    total_length='5mm',
    meander=Dict(asymmetry='50um'),
    hfss_wire_bonds= True
)

options_readq4 = Dict(
    pin_inputs=Dict(
        start_pin=Dict(
            component='Q4',
            pin='readout',
        ),
        end_pin=Dict(
            component='Q4_Read_T',
            pin='second_end',
        ),
    ),
    fillet='99um',
    lead=Dict(
        start_straight='500um',
        end_straight='25um'
    ),
    total_length='5.8mm',
    meander=Dict(asymmetry='100um'),
    hfss_wire_bonds= True
)

options_readq5 = Dict(
    pin_inputs=Dict(
        start_pin=Dict(
            component='Q5',
            pin='readout',
        ),
        end_pin=Dict(
            component='Q5_Read_T',
            pin='second_end',
        ),
    ),
    fillet='99um',
    lead=Dict(
        start_straight='500um',
        end_straight='25um'
    ),
    total_length='5.4mm',
    meander=Dict(asymmetry='100um'),
    hfss_wire_bonds= True
)


read_q3 = RouteMeander(design=design, name='Read_Q3', options=options_readq3)
read_q4 = RouteMeander(design=design, name='Read_Q4', options=options_readq4)
read_q5 = RouteMeander(design=design, name='Read_Q5', options=options_readq5)

gui.rebuild()
gui.autoscale()

# %% [markdown]
# # Analyse

# %%
from qiskit_metal.analyses.quantization import LOManalysis

chip1 = LOManalysis(design, 'q3d')

# %%
chip1.sim.setup
# Out:
# {'name': 'Setup',
#  'reuse_selected_design': True,
#  'reuse_setup': True,
#  'freq_ghz': 5.0,
#  'save_fields': False,
#  'enabled': True,
#  'max_passes': 15,
#  'min_passes': 2,
#  'min_converged_passes': 2,
#  'percent_error': 0.5,
#  'percent_refinement': 30,
#  'auto_increase_solution_order': True,
#  'solution_order': 'High',
#  'solver_type': 'Iterative'}

# %%
chip1.sim.setup.name = "Tune_Q"
chip1.sim.setup.percent_error = 0.05
chip1.sim.setup
# Out:
# {'name': 'Tune_Q',
#  'reuse_selected_design': True,
#  'reuse_setup': True,
#  'freq_ghz': 5.0,
#  'save_fields': False,
#  'enabled': True,
#  'max_passes': 15,
#  'min_passes': 2,
#  'min_converged_passes': 2,
#  'percent_error': 0.05,
#  'percent_refinement': 30,
#  'auto_increase_solution_order': True,
#  'solution_order': 'High',
#  'solver_type': 'Iterative'}

# %%
chip1.sim.run(name='Q_Main', components=['Q_Main'], open_terminations=[('Q_Main', 'readout'), ('Q_Main', 'bus_01'),('Q_Main', 'bus_02'),('Q_Main', 'bus_03'),
                                      ('Q_Main', 'bus_04'), ('Q_Main', 'bus_05')])

# %%
chip1.sim.capacitance_matrix
# Out:
# {}

# %%
# Run a LOM
chip1.setup.junctions = Dict({'Lj': 14, 'Cj': 2})
chip1.setup.freq_readout = 7.0
chip1.setup.freq_bus = [5.6, 5.7, 5.8, 5.9, 6.0]  # list of the bus frequencies

chip1.run_lom()
chip1.lumped_oscillator_all

# %%
chip1.plot_convergence();
chip1.plot_convergence_chi()

# %% [markdown]
# # EPR Analysis

# %%
from qiskit_metal.analyses.quantization import EPRanalysis
eig_qb = EPRanalysis(design, "hfss")

# %%
em_p = eig_qb.sim.setup

# %%
em_p.name = '3Modes'
em_p.min_freq_ghz = 4
em_p.n_modes = 3
em_p.max_passes = 10
em_p.max_delta_f = 0.1
em_p.min_converged = 2
# Design variables can also be added in for direct simulation sweeps.
em_p.vars = Dict({'Lj1': '13 nH', 'Cj1': '0 fF', 'Lj2': '15 nH', 'Cj2': '0 fF'})

eig_qb.sim.setup

# %%
Q_main.options.hfss_inductance

# %%
Q5.options.hfss_inductance

# %%
Q_main.options.hfss_inductance = '13nH'
Q5.options.hfss_inductance = '15nH'
bus_05.options.total_length = '7.5mm'

gui.rebuild()

# %%
eig_qb.sim.run(name="QMain_Q5_Bus05", components=['Q_Main', 'Q5','Bus_05'], open_terminations=[])

# %%
eig_qb.sim.plot_convergences()

# %%
eig_qb.del_junction()
eig_qb.add_junction('jj1', 'Lj1', 'Cj1', rect='JJ_rect_Lj_Q_Main_rect_jj', line='JJ_Lj_Q_Main_rect_jj_')
eig_qb.add_junction('jj2', 'Lj2', 'Cj2', rect='JJ_rect_Lj_Q5_rect_jj', line='JJ_Lj_Q5_rect_jj_')
eig_qb.setup.sweep_variable = 'Lj1'
eig_qb.setup

# %%
eig_qb.run_epr()

# %%
eig_qb.sim.close()

# %% [markdown]
# # GDS

# %%
full_chip_gds = design.renderers.gds

# %%
full_chip_gds.options
# Out:
# {'short_segments_to_not_fillet': 'True',
#  'check_short_segments_by_scaling_fillet': '2.0',
#  'gds_unit': 0.001,
#  'ground_plane': 'True',
#  'negative_mask': {'main': []},
#  'fabricate': 'False',
#  'corners': 'circular bend',
#  'tolerance': '0.00001',
#  'precision': '0.000000001',
#  'width_LineString': '10um',
#  'path_filename': '../resources/Fake_Junctions.GDS',
#  'junction_pad_overlap': '5um',
#  'max_points': '199',
#  'cheese': {'datatype': '100',
#   'shape': '0',
#   'cheese_0_x': '25um',
#   'cheese_0_y': '25um',
#   'cheese_1_radius': '100um',
#   'view_in_file': {'main': {1: True}},
#   'delta_x': '100um',
#   'delta_y': '100um',
#   'edge_nocheese': '200um'},
#  'no_cheese': {'datatype': '99',
#   'buffer': '25um',
#   'cap_style': '2',
#   'join_style': '2',
#   'view_in_file': {'main': {1: True}}},
#  'bounding_box_scale_x': '1.2',
#  'bounding_box_scale_y': '1.2'}

# %%
full_chip_gds.options['path_filename'] ='../resources/Fake_Junctions.GDS'
full_chip_gds.options['no_cheese']['buffer']='50um'

# %%
full_chip_gds.export_to_gds('Full_Chip_01.gds')
# Out:
# 05:40PM 42s WARNING [_import_junctions_to_one_cell]: Not able to find file:"../resources/Fake_Junctions.GDS".  Not used to replace junction. Checked directory:"c:\Users\mohamad\github\qiskit_metal\resources".
# 05:40PM 42s WARNING [_cheese_buffer_maker]: The bounding box for no-cheese is outside of chip size.
# Bounding box for chip is (-4.5, -3.0, 4.5, 3.0).
# Bounding box with no_cheese buffer is (-5.31, -4.31, 5.31, 3.1479999999999997).
# 1
